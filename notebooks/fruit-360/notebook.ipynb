# %% [markdown]
# # Neural Network models(s) with Pytorch trained on Fruits-360 data
#
# Credit for data:
# * Horea Muresan, [Mihai Oltean](https://mihaioltean.github.io), [Fruit recognition from images using deep learning](https://www.researchgate.net/publication/321475443_Fruit_recognition_from_images_using_deep_learning), Acta Univ. Sapientiae, Informatica Vol. 10, Issue 1, pp. 26-42, 2018.

# %%
# input constants
import os
import dotenv
import torch

dotenv.load_dotenv()
torch.manual_seed(42)

DATA_DIR = os.getenv('DATA_DIR')
training_data_dir = os.path.join(DATA_DIR, 'Training')
test_data_dir = os.path.join(DATA_DIR, 'Test')
partitions = list(set(os.listdir(training_data_dir)))
VALIDATION_RATIO = float(os.getenv('VALIDATION_RATIO'))

BATCH_SIZE = int(os.getenv('BATCH_SIZE'))
LEARNING_RATE = float(os.getenv('LEARNING_RATE'))
EPOCHS= int(os.getenv('EPOCHS'))

MODEL_NAME = 'sfnn'
OUTPUT_DIR = os.path.join('trained', MODEL_NAME)
HUGGINGFACE_REPO_ID = os.getenv('HUGGINGFACE_REPO_ID')

# %%
print(f"partitions ({len(partitions)} unique) first 10: {partitions[:10]}")
print(f"validation_ratio: {VALIDATION_RATIO}")
print(f"batch_size: {BATCH_SIZE}")
print(f"learning rate (lr): {LEARNING_RATE}")
print(f"epochs: {EPOCHS}")
# Out:
# partitions (131 unique) first 10: ['Peach', 'Mulberry', 'Lychee', 'Lemon Meyer', 'Chestnut', 'Carambula', 'Plum 3', 'Grape Pink', 'Dates', 'Cactus fruit']
# validation_ratio: 0.15
# batch_size: 64
# learning rate (lr): 0.001
# epochs: 5

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt

# print data dir content
print(f"DATA_DIR listdir: {os.listdir(DATA_DIR)}")

# show partition frequency
counter = {}
for p in partitions:
    p_dir = os.path.join(training_data_dir, p)
    counter[p] = len(os.listdir(p_dir))

fig, ax = plt.subplots()
ax.hist(counter.values())
ax.set_title('Histogram of partition record counts')
plt.show()
# Out:
# DATA_DIR listdir: ['test-multiple_fruits', 'readme.md', 'Training', 'Test', 'LICENSE', 'papers']

# %% [markdown]
# # Compute instance
#
# Identify hardware specification that will be used to optimise model performance.

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# # Data Ingestion
#
# Importing data files from multiple sources into storage medium(s) where it can be accessed and analyzed.
#
# The dataset will be split in 3 parts:
# * Training set: data to train the model (ex. compute the loss, adjust the model weights and bias) using the selected optimiser (ex. gradient descent).
# * Validation set: data to evaluate the model and adjust hyperparameters (ex. epochs, learning rate) and identify the best model version.
# * Test set: data to report the model accuracy.

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader

# training and validation data
dataset = datasets.ImageFolder(
    root=training_data_dir,
    transform=ToTensor()
)
classes = dataset.classes

valid_data_len = int(len(dataset) * VALIDATION_RATIO)
train_data_len = len(dataset) - valid_data_len
train_data, valid_data = torch.utils.data.random_split(
    dataset=dataset, 
    lengths=[train_data_len, valid_data_len]
)

# test data
test_data = datasets.ImageFolder(
    root=test_data_dir,
    transform=ToTensor()
)

# %%
print(f"len(train_and_valid_data): {len(dataset)}")
print(f"len(classes): {len(classes)}")
print(f"len(train_data): {len(train_data)} ({len(train_data)/len(dataset)*100:.4f}%)")
print(f"len(valid_data): {len(valid_data)} ({len(valid_data)/len(dataset)*100:.4f}%)")
print(f"len(test_data): {len(test_data)}")
# Out:
# len(train_and_valid_data): 67692
# len(classes): 131
# len(train_data): 57539 (85.0012%)
# len(valid_data): 10153 (14.9988%)
# len(test_data): 22688

# %%
import matplotlib.pyplot as plt

def img_show_single(img, label):
    fig, ax = plt.subplots(figsize=(3, 3), dpi=100)
    ax.imshow(img.permute(1, 2, 0))
    ax.set_title(f"{classes[label]} ({label})")
    
img_show_single(*train_data[1234])

# %%
train_loader = DataLoader(
    dataset=train_data, 
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2
)

valid_loader = DataLoader(
    dataset=valid_data, 
    batch_size=BATCH_SIZE * 2,
    num_workers=2
)

test_loader = DataLoader(
    dataset=test_data, 
    batch_size=BATCH_SIZE * 2,
    shuffle=True,
    num_workers=2
)

# %%
class DeviceDataLoader():
    """
    DataLoader wrapper to move data to a device
    """
    
    @classmethod
    def __to_device(cls, data, device):
        """Move tensor(s) to chosen device"""
        if isinstance(data, (list,tuple)):
            return [cls.__to_device(x, device) for x in data]
        return data.to(device, non_blocking=True)
    
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield self.__to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
train_loader = DeviceDataLoader(train_loader, device)
valid_loader = DeviceDataLoader(valid_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %%
# check shapes in first batch
for X, y in test_loader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([128, 3, 100, 100])
# Shape of y: torch.Size([128]) torch.int64

# %%
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate

# function to show an image
def img_show_grid(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get a block of training data and labels
nb_in_row = 8
xb, yb = next(iter(train_loader))
grid = torchvision.utils.make_grid(
    tensor=xb, 
    nrow=nb_in_row
)

# show images
img_show_grid(grid)

# print labels
k, m = divmod(len(yb), nb_in_row) 
yb_lists = [yb[i*nb_in_row : min((i+1)*nb_in_row, len(yb))] for i in range(k+1)]
label_lists = [[classes[y] for y in yb_list] for yb_list in yb_lists]
print(tabulate(label_lists))
# Out:
# ----------------  -------------  ---------------  ------------  --------------  --------------  ----------------  --------------
# Cherry Rainier    Banana Red     Grape White 2    Cantaloupe 1  Nectarine Flat  Cantaloupe 1    Peach 2           Pear Abate
# Lemon             Mangostan      Beetroot         Cantaloupe 2  Pepper Red      Mango Red       Onion Red Peeled  Pear Red
# Peach Flat        Nut Pecan      Tomato 2         Blueberry     Tomato Heart    Mangostan       Pepper Green      Cantaloupe 1
# Cherry Rainier    Tamarillo      Grapefruit Pink  Avocado ripe  Cocos           Pomegranate     Hazelnut          Cherry Rainier
# Mango Red         Tomato Yellow  Tangelo          Nut Pecan     Apple Red 2     Apple Golden 3  Pear Monster      Pear Stone
# Chestnut          Nut Forest     Grape Blue       Beetroot      Tomato 2        Pepino          Pepper Green      Grape White 3
# Kiwi              Pear Williams  Cucumber Ripe    Pitahaya Red  Nut Pecan       Grape Blue      Lemon Meyer       Carambula
# Cherry Wax Black  Kaki           Pear Stone       Quince        Grape White 3   Pear Forelle    Cherry 1          Tomato 2
#
# ----------------  -------------  ---------------  ------------  --------------  --------------  ----------------  --------------

# %% [markdown]
# # Model Configuration

# %% [markdown]
# ## Classification model utilities

# %%
def accuracy(
    pred: torch.Tensor, 
    labels: torch.Tensor
) -> float:
    """
    Custom accuracy metric
    """
    _, preds = torch.max(pred, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
from torch import nn
from typing import List, Dict


class ClassificationBase(nn.Module):
    """
    Base class for multilabel classification models
    """    
    def training_step(self, batch: List[torch.Tensor]) -> float:
        X, y = batch
        
        # Compute prediction error
        pred = self(X)
        loss = self._loss_fn(pred, y)
        
        return loss
    
    def validation_step(self, batch: List[torch.Tensor]) -> Dict:
        X, y = batch
        
        # Compute prediction error
        pred = self(X)
        loss = self._loss_fn(pred, y)
        
        # Compute accuracy
        acc = self._accuracy_fn(pred, y)
        return {'val_loss': loss.detach(), 'val_acc': acc}
    
    def validation_epoch_end(self, outputs: Dict) -> Dict:
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch: int, result: Dict) -> str:
        print(f"Epoch [{epoch}], \
              train_loss: {result['train_loss']:.4f}, \
              val_loss: {result['val_loss']:.4f}, \
              val_acc: {result['val_acc']:.4f}"
        )

# %%
from tqdm import tqdm
from typing import List, Dict


def evaluate(
    model: nn.Module, 
    valid_loader: DataLoader
) -> str:
    outputs = [model.validation_step(batch) for batch in valid_loader]
    return model.validation_epoch_end(outputs)


def fit(
    train_loader: DataLoader, 
    valid_loader: DataLoader, 
    model: nn.Module, 
    epochs: int, 
    lr: float,
    opt_func: callable = torch.optim.SGD,
) -> List[Dict]:
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in tqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, valid_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %% [markdown]
# ## Input data specific configuration

# %%
import random
rnd_index = random.randint(0, len(train_data))
rnd_tensor, rnd_label = train_data[rnd_index]
rnd_tensor_flat = nn.Flatten(0,-1)(rnd_tensor) 
input_dim = list(rnd_tensor_flat.size())[0]
print(f"input_dim: {input_dim}")
# Out:
# input_dim: 30000

# %%
class SimpleFeedforwardNN(ClassificationBase):
    """
    Simple feedwordward neural network 
    with a limited number of hidden layers
    """
    
    def __init__(self, input_dim, output_dim, loss_fn, accuracy_fn):
        super().__init__()
        self._loss_fn = loss_fn
        self._accuracy_fn = accuracy_fn
        self._flatten = nn.Flatten()
        self._linear_relu_stack = nn.Sequential(
            nn.Linear(input_dim, 512),  # input layer
            nn.ReLU(),
            nn.Linear(512, 256),  # hidden layer
            nn.ReLU(),
            nn.Linear(256, output_dim)  # output layer
        )
        
    def forward(self, xb):
        # flatten batch of x (xb) into vectors
        x = self._flatten(xb)
        # apply layers & activation functions
        logits = self._linear_relu_stack(x)
        return logits
    
    
model = SimpleFeedforwardNN(
    input_dim=input_dim,
    output_dim=len(classes),
    loss_fn=nn.CrossEntropyLoss(),
    accuracy_fn=accuracy
)
model = model.to(device)
print(model)
# Out:
# SimpleFeedforwardNN(
#   (_loss_fn): CrossEntropyLoss()
#   (_flatten): Flatten(start_dim=1, end_dim=-1)
#   (_linear_relu_stack): Sequential(
#     (0): Linear(in_features=30000, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=131, bias=True)
#   )
# )

# %% [markdown]
# # Training job

# %%
# performance before training
history = [evaluate(model, valid_loader)]
history
# Out:
# [{'val_loss': 4.875685691833496, 'val_acc': 0.018285537138581276}]

# %%
# training model
model.train()
history += fit(
    train_loader=train_loader,
    valid_loader=valid_loader,
    model=model,
    epochs=EPOCHS,
    lr=LEARNING_RATE,
    opt_func=torch.optim.SGD,
)
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [0],               train_loss: 4.7784,               val_loss: 4.6707,               val_acc: 0.0584
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [1],               train_loss: 4.4747,               val_loss: 4.2335,               val_acc: 0.0814
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [2],               train_loss: 3.8580,               val_loss: 3.4841,               val_acc: 0.2358
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [3],               train_loss: 3.0907,               val_loss: 2.8060,               val_acc: 0.3460
# Epoch [4],               train_loss: 2.4353,               val_loss: 2.2992,               val_acc: 0.3879

# %%
# training model (cont'd)
model.train()
history += fit(
    train_loader=train_loader,
    valid_loader=valid_loader,
    model=model,
    epochs=EPOCHS,
    lr=LEARNING_RATE/2,
    opt_func=torch.optim.SGD,
)
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [0],               train_loss: 2.0285,               val_loss: 1.9706,               val_acc: 0.5974
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [1],               train_loss: 1.8129,               val_loss: 1.7491,               val_acc: 0.6169
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [2],               train_loss: 1.6322,               val_loss: 1.5747,               val_acc: 0.6730
#   0%|          | 0/900 [00:00<?, ?it/s]
# Epoch [3],               train_loss: 1.4814,               val_loss: 1.4971,               val_acc: 0.6376
# Epoch [4],               train_loss: 1.3491,               val_loss: 1.3325,               val_acc: 0.6997

# %% [markdown]
# # Evaluations

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs')
    plt.show()
    
    
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs')
    plt.show()

# %%
plot_accuracies(history)
plot_losses(history)

# %%
model.eval()
evaluate(model, test_loader)
# Out:
# {'val_loss': 1.7393635511398315, 'val_acc': 0.5987096428871155}

# %%
from tabulate import tabulate

# get a block of test data and labels
nb_in_row = 8
xb, yb = next(iter(test_loader))
grid = torchvision.utils.make_grid(
    tensor=xb, 
    nrow=nb_in_row
)

# show images (function defined earlie)
img_show_grid(grid)

# print labels
k, m = divmod(len(yb), nb_in_row) 
yb_lists = [yb[i*nb_in_row : min((i+1)*nb_in_row, len(yb))] for i in range(k+1)]
ground_label_lists = [[classes[y] for y in yb_list] for yb_list in yb_lists]
print("Ground truth")
print(tabulate(ground_label_lists))
# Out:
# Ground truth
# ------------------  ---------------  ----------------  ------------------  --------------  -------------------  ------------------  ----------------
# Granadilla          Mandarine        Pepper Yellow     Grape Blue          Tomato 3        Avocado ripe         Apple Red 2         Kaki
# Nut Forest          Lemon            Eggplant          Cocos               Plum            Cherry Rainier       Apple Crimson Snow  Tomato 2
# Cantaloupe 2        Pear Stone       Strawberry Wedge  Orange              Tamarillo       Grape White          Blueberry           Pear Stone
# Pomelo Sweetie      Apple Pink Lady  Passion Fruit     Peach 2             Plum 2          Cherry Rainier       Lemon Meyer         Lemon Meyer
# Granadilla          Grape Pink       Tomato 1          Pomelo Sweetie      Eggplant        Huckleberry          Mulberry            Tomato 2
# Physalis with Husk  Tomato Heart     Nut Forest        Pepper Red          Kumquats        Tomato Yellow        Carambula           Clementine
# Physalis            Cactus fruit     Pepper Green      Grapefruit Pink     Tomato Heart    Pitahaya Red         Onion Red Peeled    Grape Pink
# Cherry Wax Red      Tomato Heart     Physalis          Pepper Orange       Kaki            Apple Red 1          Cherry Wax Black    Pepper Red
# Tomato 4            Dates            Grape Blue        Apple Braeburn      Mulberry        Limes                Kohlrabi            Clementine
# Walnut              Clementine       Nectarine         Nut Pecan           Banana          Pear Monster         Cherry Rainier      Potato White
# Onion White         Chestnut         Cauliflower       Apple Red Yellow 1  Tomato Heart    Grape Blue           Plum                Tomato 2
# Mango               Nut Pecan        Tomato 3          Grape White 3       Corn            Apple Red Delicious  Corn                Strawberry Wedge
# Tomato Heart        Cauliflower      Onion Red         Plum 3              Pear Stone      Apple Golden 1       Salak               Pineapple
# Kaki                Quince           Salak             Nectarine Flat      Physalis        Apple Granny Smith   Avocado             Peach
# Pear Monster        Pear Kaiser      Pear Kaiser       Tamarillo           Cherry Wax Red  Banana Red           Apple Red 3         Tamarillo
# Pepino              Tomato Heart     Cantaloupe 1      Strawberry Wedge    Pineapple Mini  Cucumber Ripe        Apple Red Yellow 2  Corn Husk
#
# ------------------  ---------------  ----------------  ------------------  --------------  -------------------  ------------------  ----------------

# %%
# prediction
logits = model(xb)
_, predicted = torch.max(logits, 1)
predicted_label_lists = [classes[y_hat] for y_hat in predicted]

ground_label_lists = [classes[y] for y in yb]
comparison = [['Match', 'Ground truth', 'Predicted'],['-'*5,'-'*10,'-'*10]]
for (gt, pred) in zip(ground_label_lists, predicted_label_lists):
    comparison.append([True if gt == pred else '', gt, pred])

print(tabulate(comparison))
# Out:
# -----  -------------------  -------------------
# Match  Ground truth         Predicted
# -----  ----------           ----------
#        Granadilla           Pear 2
#        Mandarine            Tangelo
# True   Pepper Yellow        Pepper Yellow
# True   Grape Blue           Grape Blue
# True   Tomato 3             Tomato 3
# True   Avocado ripe         Avocado ripe
# True   Apple Red 2          Apple Red 2
# True   Kaki                 Kaki
# True   Nut Forest           Nut Forest
#        Lemon                Maracuja
# True   Eggplant             Eggplant
#        Cocos                Pear Forelle
#        Plum                 Chestnut
# True   Cherry Rainier       Cherry Rainier
#        Apple Crimson Snow   Tomato 4
# True   Tomato 2             Tomato 2
#        Cantaloupe 2         Apple Golden 2
#        Pear Stone           Tomato not Ripened
#        Strawberry Wedge     Nut Pecan
# True   Orange               Orange
# True   Tamarillo            Tamarillo
# True   Grape White          Grape White
# True   Blueberry            Blueberry
#        Pear Stone           Walnut
# True   Pomelo Sweetie       Pomelo Sweetie
#        Apple Pink Lady      Onion White
# True   Passion Fruit        Passion Fruit
# True   Peach 2              Peach 2
# True   Plum 2               Plum 2
#        Cherry Rainier       Cantaloupe 2
# True   Lemon Meyer          Lemon Meyer
# True   Lemon Meyer          Lemon Meyer
#        Granadilla           Pear 2
# True   Grape Pink           Grape Pink
# True   Tomato 1             Tomato 1
# True   Pomelo Sweetie       Pomelo Sweetie
#        Eggplant             Pear Forelle
# True   Huckleberry          Huckleberry
#        Mulberry             Dates
# True   Tomato 2             Tomato 2
# True   Physalis with Husk   Physalis with Husk
# True   Tomato Heart         Tomato Heart
# True   Nut Forest           Nut Forest
#        Pepper Red           Tomato Heart
# True   Kumquats             Kumquats
# True   Tomato Yellow        Tomato Yellow
# True   Carambula            Carambula
# True   Clementine           Clementine
# True   Physalis             Physalis
# True   Cactus fruit         Cactus fruit
# True   Pepper Green         Pepper Green
# True   Grapefruit Pink      Grapefruit Pink
# True   Tomato Heart         Tomato Heart
# True   Pitahaya Red         Pitahaya Red
#        Onion Red Peeled     Pear Forelle
# True   Grape Pink           Grape Pink
# True   Cherry Wax Red       Cherry Wax Red
# True   Tomato Heart         Tomato Heart
# True   Physalis             Physalis
# True   Pepper Orange        Pepper Orange
# True   Kaki                 Kaki
#        Apple Red 1          Grape Pink
# True   Cherry Wax Black     Cherry Wax Black
#        Pepper Red           Nectarine Flat
# True   Tomato 4             Tomato 4
# True   Dates                Dates
# True   Grape Blue           Grape Blue
# True   Apple Braeburn       Apple Braeburn
# True   Mulberry             Mulberry
#        Limes                Apple Granny Smith
#        Kohlrabi             Pear Forelle
# True   Clementine           Clementine
# True   Walnut               Walnut
# True   Clementine           Clementine
#        Nectarine            Apricot
# True   Nut Pecan            Nut Pecan
#        Banana               Pear 2
#        Pear Monster         Pepino
#        Cherry Rainier       Cantaloupe 2
#        Potato White         Pear Forelle
# True   Onion White          Onion White
#        Chestnut             Avocado
#        Cauliflower          Walnut
# True   Apple Red Yellow 1   Apple Red Yellow 1
# True   Tomato Heart         Tomato Heart
#        Grape Blue           Plum 3
# True   Plum                 Plum
# True   Tomato 2             Tomato 2
# True   Mango                Mango
#        Nut Pecan            Apple Red 3
# True   Tomato 3             Tomato 3
# True   Grape White 3        Grape White 3
#        Corn                 Pear 2
# True   Apple Red Delicious  Apple Red Delicious
# True   Corn                 Corn
# True   Strawberry Wedge     Strawberry Wedge
# True   Tomato Heart         Tomato Heart
# True   Cauliflower          Cauliflower
#        Onion Red            Pear Forelle
# True   Plum 3               Plum 3
#        Pear Stone           Pear Forelle
# True   Apple Golden 1       Apple Golden 1
#        Salak                Hazelnut
#        Pineapple            Pear Forelle
# True   Kaki                 Kaki
# True   Quince               Quince
#        Salak                Hazelnut
#        Nectarine Flat       Tomato 4
# True   Physalis             Physalis
# True   Apple Granny Smith   Apple Granny Smith
# True   Avocado              Avocado
#        Peach                Apple Red Yellow 1
#        Pear Monster         Physalis with Husk
#        Pear Kaiser          Melon Piel de Sapo
#        Pear Kaiser          Pear Forelle
# True   Tamarillo            Tamarillo
# True   Cherry Wax Red       Cherry Wax Red
#        Banana Red           Corn Husk
#        Apple Red 3          Apple Braeburn
#        Tamarillo            Strawberry
#        Pepino               Pear
# True   Tomato Heart         Tomato Heart
# True   Cantaloupe 1         Cantaloupe 1
# True   Strawberry Wedge     Strawberry Wedge
# True   Pineapple Mini       Pineapple Mini
#        Cucumber Ripe        Pear Forelle
#        Apple Red Yellow 2   Pear Forelle
#        Corn Husk            Grape White
# -----  -------------------  -------------------

# %% [markdown]
# # Store Model

# %%
# save locally
import os

output_file_path = os.path(OUTPUT_DIR, f"{MODEL_NAME}.pth")
torch.save(model.state_dict(), output_file_path)
print(f"Saved model {output_file_path}")
# Out:
# Saved model SSNN.pth

# %%
## Save on HuggingFace
# Requires 
# 1. access token from `https://huggingface.co/settings/tokens`
# 2. terminal login: `huggingface-cli login`

from huggingface_hub import create_repo, upload_file

try:
    repo = create_repo(repo_id=HUGGINGFACE_REPO_ID)
except Exception as ex:
    print(ex)

upload_file(
    path_or_fileobj=f"./{MODEL_NAME}.pth",
    path_in_repo=f"/models/{MODEL_NAME}.pth",
    repo_id=HUGGINGFACE_REPO_ID,
)
# Out:
# 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create (Request ID: Root=1-66a2261f-7c3087306996b9de40ba5edf;b0807bff-9ac8-4634-b58d-569f90b72e86)
#
# You already created this model repo
# sfnn.pth:   0%|          | 0.00/62.1M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ptbdnr/icook-recogniser/commit/75394c73f7ce5ba3641af2a3f919345f9f86a0ac', commit_message='Upload /models/sfnn.pth with huggingface_hub', commit_description='', oid='75394c73f7ce5ba3641af2a3f919345f9f86a0ac', pr_url=None, pr_revision=None, pr_num=None)
